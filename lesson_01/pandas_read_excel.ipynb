# %%
import os
import pandas as pd

pd.read_excel('../elementos.xlsx', header=2)
# Out:
#        Codigo Codigo Padre Tipo Producto Tipo Elemento Revision  \
# 0    2G1_V293          NaN         ELEME          ESTR        0
# 1    2G1_V293     2G1_V293           NaN           NaN
# 2      2G1_b5     2G1_V293           NaN           NaN
# 3   2G1_p1105     2G1_V293           NaN           NaN
# 4   2G1_p1200     2G1_V293           NaN           NaN
# 5   2G1_p1288     2G1_V293           NaN           NaN
# 6   2G1_p1289     2G1_V293           NaN           NaN
# 7   2G1_p1318     2G1_V293           NaN           NaN
# 8   2G1_p1373     2G1_V293           NaN           NaN
# 9   2G1_p1383     2G1_V293           NaN           NaN
# 10  2G1_p1392     2G1_V293           NaN           NaN
# 11   2G1_V305          NaN         ELEME          ESTR        0
# 12   2G1_V305     2G1_V305           NaN           NaN
# 13     2G1_b4     2G1_V305           NaN           NaN
# 14  2G1_p1105     2G1_V305           NaN           NaN
# 15  2G1_p1200     2G1_V305           NaN           NaN
# ...
